# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import warnings
warnings.filterwarnings("ignore")

# %%
read = pd.read_csv('H2HBABBA1887.csv')
df = pd.DataFrame(read)
df.dtypes
# Out:
# business_code              object
# cust_number                object
# name_customer              object
# clear_date                 object
# buisness_year             float64
# doc_id                    float64
# posting_date               object
# document_create_date        int64
# document_create_date.1      int64
# due_in_date               float64
# invoice_currency           object
# document type              object
# posting_id                float64
# area_business             float64
# total_open_amount         float64
# baseline_create_date      float64
# cust_payment_terms         object
# invoice_id                float64
# isOpen                      int64
# dtype: object

# %%
df.head()
# Out:
#   business_code cust_number       name_customer           clear_date  \
# 0          U001  0200769623          WAL-MAR in                  NaN
# 1          U001  0200729828  KENNETH foundation  2019-09-25 00:00:00
# 2          U001      CCU013       KRAFT F trust                  NaN
# 3          U001  0200780383             MEIJ us  2019-09-30 00:00:00
# 4          U001  0200792293          UNIFIE llc  2019-11-22 00:00:00
#
#    buisness_year        doc_id posting_date  document_create_date  \
# 0         2020.0  1.930815e+09   2020-04-28              20200422
# 1         2019.0  1.929826e+09   2019-09-06              20190903
# 2         2020.0  1.930666e+09   2020-03-16              20200317
# 3         2019.0  1.929852e+09   2019-09-09              20190909
# 4         2019.0  1.930113e+09   2019-11-05              20191105
#
#    document_create_date.1  due_in_date invoice_currency document type  \
# 0                20200428   20200513.0              USD            RV
# 1                20190906   20190926.0              USD            RV
# 2                20200316   20200316.0              USD            RV
# 3                20190909   20190924.0              USD            RV
# 4                20191105   20191120.0              USD            RV
#
#    posting_id  area_business  total_open_amount  baseline_create_date  \
# 0         1.0            NaN            6361.07            20200428.0
# 1         1.0            NaN           27848.46            20190906.0
# 2         1.0            NaN            5095.68            20200316.0
# 3         1.0            NaN           81781.59            20190909.0
# 4         1.0            NaN           67352.17            20191105.0
#
#   cust_payment_terms    invoice_id  isOpen
# 0               NAH4  1.930815e+09       1
# 1               NAD1  1.929826e+09       0
# 2               NAX2  1.930666e+09       1
# 3               NAA8  1.929852e+09       0
# 4               NAA8  1.930113e+09       0

# %%
# Removing NaN(area_business) column
df = df.drop(['area_business'], axis=1)
df.shape
# Out:
# (50000, 18)

# %%
testData = df[df.clear_date.isnull()]
testData.shape
# Out:
# (10000, 18)

# %%
trainData = df[df.clear_date.notnull()]
trainData.shape
# Out:
# (40000, 18)

# %%
trainData['clear_date'] = pd.to_datetime(trainData.clear_date)
trainData['posting_date'] = pd.to_datetime(trainData.posting_date)

trainData['document_create_date'] = pd.to_datetime(trainData['document_create_date'], format='%Y%m%d')
trainData['document_create_date.1'] = pd.to_datetime(trainData['document_create_date.1'], format='%Y%m%d')

trainData['due_in_date'] = trainData['due_in_date'].astype(int)
trainData['baseline_create_date'] = trainData['baseline_create_date'].astype(int)

trainData['due_in_date'] = pd.to_datetime(trainData['due_in_date'], format='%Y%m%d')
trainData['baseline_create_date'] = pd.to_datetime(trainData['baseline_create_date'], format='%Y%m%d')
trainData.head()
# Out:
#   business_code cust_number       name_customer clear_date  buisness_year  \
# 1          U001  0200729828  KENNETH foundation 2019-09-25         2019.0
# 3          U001  0200780383             MEIJ us 2019-09-30         2019.0
# 4          U001  0200792293          UNIFIE llc 2019-11-22         2019.0
# 5          U001  0200833713           JETRO llc 2019-04-09         2019.0
# 6          U001  0200769623        WAL-MAR corp 2020-02-24         2020.0
#
#          doc_id posting_date document_create_date document_create_date.1  \
# 1  1.929826e+09   2019-09-06           2019-09-03             2019-09-06
# 3  1.929852e+09   2019-09-09           2019-09-09             2019-09-09
# 4  1.930113e+09   2019-11-05           2019-11-05             2019-11-05
# 5  1.929002e+09   2019-03-20           2019-03-20             2019-03-20
# 6  1.930510e+09   2020-02-10           2020-02-10             2020-02-10
#
#   due_in_date invoice_currency document type  posting_id  total_open_amount  \
# 1  2019-09-26              USD            RV         1.0           27848.46
# 3  2019-09-24              USD            RV         1.0           81781.59
# 4  2019-11-20              USD            RV         1.0           67352.17
# 5  2019-04-04              USD            RV         1.0            1696.56
# 6  2020-02-25              USD            RV         1.0           14213.45
#
#   baseline_create_date cust_payment_terms    invoice_id  isOpen
# 1           2019-09-06               NAD1  1.929826e+09       0
# 3           2019-09-09               NAA8  1.929852e+09       0
# 4           2019-11-05               NAA8  1.930113e+09       0
# 5           2019-03-20               NAA8  1.929002e+09       0
# 6           2020-02-10               NAH4  1.930510e+09       0

# %%
# using to ordinal function to convert time date to proleptic Gregorian ordinal (no. of days from 01/01/01 to current date)
trainData['clear_date']=trainData['clear_date'].map(dt.datetime.toordinal)
trainData['posting_date']=trainData['posting_date'].map(dt.datetime.toordinal)
trainData['document_create_date']=trainData['document_create_date'].map(dt.datetime.toordinal)
trainData['document_create_date.1']=trainData['document_create_date.1'].map(dt.datetime.toordinal)
trainData['due_in_date']=trainData['due_in_date'].map(dt.datetime.toordinal)
trainData['baseline_create_date']=trainData['baseline_create_date'].map(dt.datetime.toordinal)

trainData.dtypes
# Out:
# business_code              object
# cust_number                object
# name_customer              object
# clear_date                  int64
# buisness_year             float64
# doc_id                    float64
# posting_date                int64
# document_create_date        int64
# document_create_date.1      int64
# due_in_date                 int64
# invoice_currency           object
# document type              object
# posting_id                float64
# total_open_amount         float64
# baseline_create_date        int64
# cust_payment_terms         object
# invoice_id                float64
# isOpen                      int64
# dtype: object

# %%
trainData.sort_values(['posting_date'], inplace=True, ignore_index=False)
trainData.head()
# Out:
#       business_code cust_number       name_customer  clear_date  \
# 16374          U001  0200769623          WAL-MAR in      737068
# 34352          U001  0200769623            WAL-MAR       737068
# 26036          U001  0200769623            WAL-MAR       737074
# 14040          U001      CCU013  KRAFT F foundation      737119
# 14023          U001  0200726979            BJ'S  us      737074
#
#        buisness_year        doc_id  posting_date  document_create_date  \
# 16374         2019.0  1.928539e+09        737058                737057
# 34352         2019.0  1.928534e+09        737058                737057
# 26036         2019.0  1.928542e+09        737058                737057
# 14040         2019.0  1.928517e+09        737058                737059
# 14023         2019.0  1.928539e+09        737058                737057
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 16374                  737058       737073              USD            RV
# 34352                  737058       737073              USD            RV
# 26036                  737058       737073              USD            RV
# 14040                  737058       737058              USD            RV
# 14023                  737058       737073              USD            RV
#
#        posting_id  total_open_amount  baseline_create_date cust_payment_terms  \
# 16374         1.0            4763.88                737058               NAH4
# 34352         1.0           15753.54                737058               NAH4
# 26036         1.0           12491.86                737058               NAH4
# 14040         1.0           17592.60                737058               NAX2
# 14023         1.0             116.38                737058               NAA8
#
#          invoice_id  isOpen
# 16374  1.928539e+09       0
# 34352  1.928534e+09       0
# 26036  1.928542e+09       0
# 14040  1.928517e+09       0
# 14023  1.928539e+09       0

# %%
trainData.isnull().mean()
# Out:
# business_code             0.000000
# cust_number               0.000000
# name_customer             0.000000
# clear_date                0.000000
# buisness_year             0.000000
# doc_id                    0.000000
# posting_date              0.000000
# document_create_date      0.000000
# document_create_date.1    0.000000
# due_in_date               0.000000
# invoice_currency          0.000000
# document type             0.000000
# posting_id                0.000000
# total_open_amount         0.000000
# baseline_create_date      0.000000
# cust_payment_terms        0.000000
# invoice_id                0.000225
# isOpen                    0.000000
# dtype: float64

# %%
trainData.dropna(subset=["invoice_id"],inplace=True)
trainData.shape
# Out:
# (39991, 18)

# %%
trainData.isnull().sum()
# Out:
# business_code             0
# cust_number               0
# name_customer             0
# clear_date                0
# buisness_year             0
# doc_id                    0
# posting_date              0
# document_create_date      0
# document_create_date.1    0
# due_in_date               0
# invoice_currency          0
# document type             0
# posting_id                0
# total_open_amount         0
# baseline_create_date      0
# cust_payment_terms        0
# invoice_id                0
# isOpen                    0
# dtype: int64

# %%
trainData.duplicated().sum()
# Out:
# 868

# %%
trainData.loc[trainData.duplicated(), :]
# Out:
#       business_code cust_number      name_customer  clear_date  buisness_year  \
# 5514           U001  0200769623       WAL-MAR corp      737074         2019.0
# 28673          U001  0200726979           BJ'S  us      737074         2019.0
# 5482           U001  0200769623         WAL-MAR co      737068         2019.0
# 10144          U001  0200769623           WAL-MAR       737073         2019.0
# 30073          U001  0200078795   H T H associates      737081         2019.0
# ...             ...         ...                ...         ...            ...
# 28173          U001  0200723794          MID MO co      737556         2020.0
# 30778          U001  0200726979  BJ'S  corporation      737495         2020.0
# 30669          U001  0200769623    WAL-MAR systems      737497         2020.0
# 23989          U001  0200707822        PUBLI trust      737495         2020.0
# 27991          U001      CCCA02     KRAFT  systems      737511         2020.0
#
#              doc_id  posting_date  document_create_date  \
# 5514   1.928541e+09        737058                737057
# 28673  1.928539e+09        737058                737057
# 5482   1.928539e+09        737058                737057
# 10144  1.928547e+09        737061                737060
# 30073  1.928554e+09        737061                737061
# ...             ...           ...                   ...
# 28173  1.930565e+09        737479                737479
# 30778  1.930565e+09        737480                737479
# 30669  1.930566e+09        737480                737480
# 23989  1.930566e+09        737480                737480
# 27991  1.930565e+09        737481                737479
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 5514                   737058       737073              USD            RV
# 28673                  737058       737073              USD            RV
# 5482                   737058       737073              USD            RV
# 10144                  737061       737076              USD            RV
# 30073                  737061       737076              USD            RV
# ...                       ...          ...              ...           ...
# 28173                  737479       737544              USD            RV
# 30778                  737480       737495              USD            RV
# 30669                  737480       737495              USD            RV
# 23989                  737480       737495              USD            RV
# 27991                  737481       737516              USD            RV
#
#        posting_id  total_open_amount  baseline_create_date cust_payment_terms  \
# 5514          1.0           11682.88                737058               NAH4
# 28673         1.0             116.38                737058               NAA8
# 5482          1.0           11582.37                737058               NAH4
# 10144         1.0              15.74                737061               NAH4
# 30073         1.0             851.26                737061               NAA8
# ...           ...                ...                   ...                ...
# 28173         1.0             865.54                737479               NAGD
# 30778         1.0             221.57                737480               NAA8
# 30669         1.0            4872.22                737480               NAH4
# 23989         1.0           63921.25                737480               NAA8
# 27991         1.0           15391.50                737481               NAG2
#
#          invoice_id  isOpen
# 5514   1.928541e+09       0
# 28673  1.928539e+09       0
# 5482   1.928539e+09       0
# 10144  1.928547e+09       0
# 30073  1.928554e+09       0
# ...             ...     ...
# 28173  1.930565e+09       0
# 30778  1.930565e+09       0
# 30669  1.930566e+09       0
# 23989  1.930566e+09       0
# 27991  1.930565e+09       0
#
# [868 rows x 18 columns]

# %%
trainData.drop_duplicates(keep='first', inplace=True)
trainData.shape
# Out:
# (39123, 18)

# %%
trainData.dtypes
# Out:
# business_code              object
# cust_number                object
# name_customer              object
# clear_date                  int64
# buisness_year             float64
# doc_id                    float64
# posting_date                int64
# document_create_date        int64
# document_create_date.1      int64
# due_in_date                 int64
# invoice_currency           object
# document type              object
# posting_id                float64
# total_open_amount         float64
# baseline_create_date        int64
# cust_payment_terms         object
# invoice_id                float64
# isOpen                      int64
# dtype: object

# %%
from sklearn.feature_selection import VarianceThreshold
trainData.head()
# Out:
#       business_code cust_number       name_customer  clear_date  \
# 16374          U001  0200769623          WAL-MAR in      737068
# 34352          U001  0200769623            WAL-MAR       737068
# 26036          U001  0200769623            WAL-MAR       737074
# 14040          U001      CCU013  KRAFT F foundation      737119
# 14023          U001  0200726979            BJ'S  us      737074
#
#        buisness_year        doc_id  posting_date  document_create_date  \
# 16374         2019.0  1.928539e+09        737058                737057
# 34352         2019.0  1.928534e+09        737058                737057
# 26036         2019.0  1.928542e+09        737058                737057
# 14040         2019.0  1.928517e+09        737058                737059
# 14023         2019.0  1.928539e+09        737058                737057
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 16374                  737058       737073              USD            RV
# 34352                  737058       737073              USD            RV
# 26036                  737058       737073              USD            RV
# 14040                  737058       737058              USD            RV
# 14023                  737058       737073              USD            RV
#
#        posting_id  total_open_amount  baseline_create_date cust_payment_terms  \
# 16374         1.0            4763.88                737058               NAH4
# 34352         1.0           15753.54                737058               NAH4
# 26036         1.0           12491.86                737058               NAH4
# 14040         1.0           17592.60                737058               NAX2
# 14023         1.0             116.38                737058               NAA8
#
#          invoice_id  isOpen
# 16374  1.928539e+09       0
# 34352  1.928534e+09       0
# 26036  1.928542e+09       0
# 14040  1.928517e+09       0
# 14023  1.928539e+09       0

# %%
trainData.dtypes
# Out:
# business_code              object
# cust_number                object
# name_customer              object
# clear_date                  int64
# buisness_year             float64
# doc_id                    float64
# posting_date                int64
# document_create_date        int64
# document_create_date.1      int64
# due_in_date                 int64
# invoice_currency           object
# document type              object
# posting_id                float64
# total_open_amount         float64
# baseline_create_date        int64
# cust_payment_terms         object
# invoice_id                float64
# isOpen                      int64
# dtype: object

# %%
trainDataTemp = trainData.select_dtypes(exclude=['object'])
trainData.head()
# Out:
#       business_code cust_number       name_customer  clear_date  \
# 16374          U001  0200769623          WAL-MAR in      737068
# 34352          U001  0200769623            WAL-MAR       737068
# 26036          U001  0200769623            WAL-MAR       737074
# 14040          U001      CCU013  KRAFT F foundation      737119
# 14023          U001  0200726979            BJ'S  us      737074
#
#        buisness_year        doc_id  posting_date  document_create_date  \
# 16374         2019.0  1.928539e+09        737058                737057
# 34352         2019.0  1.928534e+09        737058                737057
# 26036         2019.0  1.928542e+09        737058                737057
# 14040         2019.0  1.928517e+09        737058                737059
# 14023         2019.0  1.928539e+09        737058                737057
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 16374                  737058       737073              USD            RV
# 34352                  737058       737073              USD            RV
# 26036                  737058       737073              USD            RV
# 14040                  737058       737058              USD            RV
# 14023                  737058       737073              USD            RV
#
#        posting_id  total_open_amount  baseline_create_date cust_payment_terms  \
# 16374         1.0            4763.88                737058               NAH4
# 34352         1.0           15753.54                737058               NAH4
# 26036         1.0           12491.86                737058               NAH4
# 14040         1.0           17592.60                737058               NAX2
# 14023         1.0             116.38                737058               NAA8
#
#          invoice_id  isOpen
# 16374  1.928539e+09       0
# 34352  1.928534e+09       0
# 26036  1.928542e+09       0
# 14040  1.928517e+09       0
# 14023  1.928539e+09       0

# %%
varThresh = VarianceThreshold(threshold=0)
varThresh.fit(trainDataTemp)
# Out:
# VarianceThreshold(threshold=0)

# %%
varThresh.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True, False,  True,
#         True,  True, False])

# %%
trainDataTemp.columns[varThresh.get_support()]
# Out:
# Index(['clear_date', 'buisness_year', 'doc_id', 'posting_date',
#        'document_create_date', 'document_create_date.1', 'due_in_date',
#        'total_open_amount', 'baseline_create_date', 'invoice_id'],
#       dtype='object')

# %%
constCol = [column for column in trainDataTemp.columns
            if column not in trainDataTemp.columns[varThresh.get_support()]]

for features in constCol:
    print(features)
# Out:
# posting_id
# isOpen

# %%
trainData.drop(constCol, axis=1, inplace=True)
trainData.head()
# Out:
#       business_code cust_number       name_customer  clear_date  \
# 16374          U001  0200769623          WAL-MAR in      737068
# 34352          U001  0200769623            WAL-MAR       737068
# 26036          U001  0200769623            WAL-MAR       737074
# 14040          U001      CCU013  KRAFT F foundation      737119
# 14023          U001  0200726979            BJ'S  us      737074
#
#        buisness_year        doc_id  posting_date  document_create_date  \
# 16374         2019.0  1.928539e+09        737058                737057
# 34352         2019.0  1.928534e+09        737058                737057
# 26036         2019.0  1.928542e+09        737058                737057
# 14040         2019.0  1.928517e+09        737058                737059
# 14023         2019.0  1.928539e+09        737058                737057
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 16374                  737058       737073              USD            RV
# 34352                  737058       737073              USD            RV
# 26036                  737058       737073              USD            RV
# 14040                  737058       737058              USD            RV
# 14023                  737058       737073              USD            RV
#
#        total_open_amount  baseline_create_date cust_payment_terms  \
# 16374            4763.88                737058               NAH4
# 34352           15753.54                737058               NAH4
# 26036           12491.86                737058               NAH4
# 14040           17592.60                737058               NAX2
# 14023             116.38                737058               NAA8
#
#          invoice_id
# 16374  1.928539e+09
# 34352  1.928534e+09
# 26036  1.928542e+09
# 14040  1.928517e+09
# 14023  1.928539e+09

# %%
trainData.shape
# Out:
# (39123, 16)

# %%
trainDataTemp = trainData.select_dtypes(exclude=['object'])
trainData.head()
# Out:
#       business_code cust_number       name_customer  clear_date  \
# 16374          U001  0200769623          WAL-MAR in      737068
# 34352          U001  0200769623            WAL-MAR       737068
# 26036          U001  0200769623            WAL-MAR       737074
# 14040          U001      CCU013  KRAFT F foundation      737119
# 14023          U001  0200726979            BJ'S  us      737074
#
#        buisness_year        doc_id  posting_date  document_create_date  \
# 16374         2019.0  1.928539e+09        737058                737057
# 34352         2019.0  1.928534e+09        737058                737057
# 26036         2019.0  1.928542e+09        737058                737057
# 14040         2019.0  1.928517e+09        737058                737059
# 14023         2019.0  1.928539e+09        737058                737057
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 16374                  737058       737073              USD            RV
# 34352                  737058       737073              USD            RV
# 26036                  737058       737073              USD            RV
# 14040                  737058       737058              USD            RV
# 14023                  737058       737073              USD            RV
#
#        total_open_amount  baseline_create_date cust_payment_terms  \
# 16374            4763.88                737058               NAH4
# 34352           15753.54                737058               NAH4
# 26036           12491.86                737058               NAH4
# 14040           17592.60                737058               NAX2
# 14023             116.38                737058               NAA8
#
#          invoice_id
# 16374  1.928539e+09
# 34352  1.928534e+09
# 26036  1.928542e+09
# 14040  1.928517e+09
# 14023  1.928539e+09

# %%
varThresh = VarianceThreshold(threshold=0.3)
varThresh.fit(trainDataTemp)
# Out:
# VarianceThreshold(threshold=0.3)

# %%
varSupp = varThresh.get_support()
varSupp
# Out:
# array([ True, False,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
trainDataTemp.columns[varSupp]
# Out:
# Index(['clear_date', 'doc_id', 'posting_date', 'document_create_date',
#        'document_create_date.1', 'due_in_date', 'total_open_amount',
#        'baseline_create_date', 'invoice_id'],
#       dtype='object')

# %%
quasiCol = [column for column in trainDataTemp.columns
            if column not in trainDataTemp.columns[varSupp]]

for features in quasiCol:
    print(features)
# Out:
# buisness_year

# %%
trainData.drop(quasiCol, axis=1, inplace=True)
print(trainData.shape)
trainData.head()
# Out:
# (39123, 15)
#       business_code cust_number       name_customer  clear_date        doc_id  \
# 16374          U001  0200769623          WAL-MAR in      737068  1.928539e+09
# 34352          U001  0200769623            WAL-MAR       737068  1.928534e+09
# 26036          U001  0200769623            WAL-MAR       737074  1.928542e+09
# 14040          U001      CCU013  KRAFT F foundation      737119  1.928517e+09
# 14023          U001  0200726979            BJ'S  us      737074  1.928539e+09
#
#        posting_date  document_create_date  document_create_date.1  \
# 16374        737058                737057                  737058
# 34352        737058                737057                  737058
# 26036        737058                737057                  737058
# 14040        737058                737059                  737058
# 14023        737058                737057                  737058
#
#        due_in_date invoice_currency document type  total_open_amount  \
# 16374       737073              USD            RV            4763.88
# 34352       737073              USD            RV           15753.54
# 26036       737073              USD            RV           12491.86
# 14040       737058              USD            RV           17592.60
# 14023       737073              USD            RV             116.38
#
#        baseline_create_date cust_payment_terms    invoice_id
# 16374                737058               NAH4  1.928539e+09
# 34352                737058               NAH4  1.928534e+09
# 26036                737058               NAH4  1.928542e+09
# 14040                737058               NAX2  1.928517e+09
# 14023                737058               NAA8  1.928539e+09

# %%
for col in trainData:
    if trainData[col].dtypes == object:
        print(col , ' : ', len(trainData[col].unique()))
# Out:
# business_code  :  6
# cust_number  :  1348
# name_customer  :  3912
# invoice_currency  :  2
# document type  :  1
# cust_payment_terms  :  70

# %%
trainDataFrqMap = trainData.business_code.value_counts().to_dict()
trainData.business_code = trainData.business_code.map(trainDataFrqMap)
trainData.head()
# Out:
#        business_code cust_number       name_customer  clear_date  \
# 16374          35430  0200769623          WAL-MAR in      737068
# 34352          35430  0200769623            WAL-MAR       737068
# 26036          35430  0200769623            WAL-MAR       737074
# 14040          35430      CCU013  KRAFT F foundation      737119
# 14023          35430  0200726979            BJ'S  us      737074
#
#              doc_id  posting_date  document_create_date  \
# 16374  1.928539e+09        737058                737057
# 34352  1.928534e+09        737058                737057
# 26036  1.928542e+09        737058                737057
# 14040  1.928517e+09        737058                737059
# 14023  1.928539e+09        737058                737057
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 16374                  737058       737073              USD            RV
# 34352                  737058       737073              USD            RV
# 26036                  737058       737073              USD            RV
# 14040                  737058       737058              USD            RV
# 14023                  737058       737073              USD            RV
#
#        total_open_amount  baseline_create_date cust_payment_terms  \
# 16374            4763.88                737058               NAH4
# 34352           15753.54                737058               NAH4
# 26036           12491.86                737058               NAH4
# 14040           17592.60                737058               NAX2
# 14023             116.38                737058               NAA8
#
#          invoice_id
# 16374  1.928539e+09
# 34352  1.928534e+09
# 26036  1.928542e+09
# 14040  1.928517e+09
# 14023  1.928539e+09

# %%
trainDataTemp = pd.get_dummies(trainData['invoice_currency'], drop_first=True)
trainData = pd.concat([trainDataTemp, trainData], axis=1)

# %%
trainData.drop('invoice_currency', axis=1, inplace=True)
trainData.head()
# Out:
#        USD  business_code cust_number       name_customer  clear_date  \
# 16374    1          35430  0200769623          WAL-MAR in      737068
# 34352    1          35430  0200769623            WAL-MAR       737068
# 26036    1          35430  0200769623            WAL-MAR       737074
# 14040    1          35430      CCU013  KRAFT F foundation      737119
# 14023    1          35430  0200726979            BJ'S  us      737074
#
#              doc_id  posting_date  document_create_date  \
# 16374  1.928539e+09        737058                737057
# 34352  1.928534e+09        737058                737057
# 26036  1.928542e+09        737058                737057
# 14040  1.928517e+09        737058                737059
# 14023  1.928539e+09        737058                737057
#
#        document_create_date.1  due_in_date document type  total_open_amount  \
# 16374                  737058       737073            RV            4763.88
# 34352                  737058       737073            RV           15753.54
# 26036                  737058       737073            RV           12491.86
# 14040                  737058       737058            RV           17592.60
# 14023                  737058       737073            RV             116.38
#
#        baseline_create_date cust_payment_terms    invoice_id
# 16374                737058               NAH4  1.928539e+09
# 34352                737058               NAH4  1.928534e+09
# 26036                737058               NAH4  1.928542e+09
# 14040                737058               NAX2  1.928517e+09
# 14023                737058               NAA8  1.928539e+09

# %%
trainData.shape
# Out:
# (39123, 15)

# %%
trainData.drop(['cust_number','name_customer','document type','document_create_date.1'] , axis = 1 , inplace = True)
trainData.shape
# Out:
# (39123, 11)

# %%
trainData['delay'] = trainData['clear_date'] - trainData['due_in_date']
trainData.head()
# Out:
#        USD  business_code  clear_date        doc_id  posting_date  \
# 16374    1          35430      737068  1.928539e+09        737058
# 34352    1          35430      737068  1.928534e+09        737058
# 26036    1          35430      737074  1.928542e+09        737058
# 14040    1          35430      737119  1.928517e+09        737058
# 14023    1          35430      737074  1.928539e+09        737058
#
#        document_create_date  due_in_date  total_open_amount  \
# 16374                737057       737073            4763.88
# 34352                737057       737073           15753.54
# 26036                737057       737073           12491.86
# 14040                737059       737058           17592.60
# 14023                737057       737073             116.38
#
#        baseline_create_date cust_payment_terms    invoice_id  delay
# 16374                737058               NAH4  1.928539e+09     -5
# 34352                737058               NAH4  1.928534e+09     -5
# 26036                737058               NAH4  1.928542e+09      1
# 14040                737058               NAX2  1.928517e+09     61
# 14023                737058               NAA8  1.928539e+09      1

# %%
trainDataFrqMap = trainData.cust_payment_terms.value_counts().to_dict()
trainDataFrqMap
# Out:
# {'NAA8': 15535,
#  'NAH4': 10477,
#  'CA10': 2980,
#  'NAC6': 1371,
#  'NAM4': 1031,
#  'NAAX': 991,
#  'NAD1': 777,
#  'NAG2': 706,
#  'NAU5': 663,
#  'NA32': 625,
#  'NAGD': 617,
#  'NAX2': 565,
#  'NAM2': 462,
#  'NA10': 325,
#  'NAD5': 271,
#  'NAM1': 235,
#  'NAVE': 228,
#  'NAVF': 199,
#  'NAAW': 165,
#  'NAVQ': 104,
#  'NAWU': 100,
#  'NAWN': 94,
#  'NAVR': 82,
#  'NAWP': 54,
#  'NAUZ': 51,
#  'NAVM': 40,
#  'NABG': 38,
#  'NACB': 37,
#  'NA3B': 36,
#  'CA30': 32,
#  'NA38': 26,
#  'NAD4': 24,
#  'C106': 19,
#  'NAB1': 17,
#  'NAVL': 17,
#  'NA84': 16,
#  'NAUP': 11,
#  'NA9X': 9,
#  'BR56': 8,
#  'NAM3': 8,
#  'NAVC': 8,
#  'NA3F': 6,
#  'NATW': 5,
#  'CAB1': 5,
#  'NAD8': 5,
#  'NA31': 5,
#  'NA25': 4,
#  'NAVD': 4,
#  'NAUX': 3,
#  'NAWM': 3,
#  'NATU': 3,
#  'CAX2': 3,
#  'NATX': 2,
#  'B052': 2,
#  'NAV9': 2,
#  '90M7': 2,
#  'NA8Q': 2,
#  'NATJ': 1,
#  'C129': 1,
#  'NATZ': 1,
#  'BR12': 1,
#  'CA60': 1,
#  'NA24': 1,
#  'NAUW': 1,
#  'B112': 1,
#  'NATH': 1,
#  'NATM': 1,
#  'NAUI': 1,
#  'NANC': 1,
#  'NACE': 1}

# %%
trainData.cust_payment_terms = trainData.cust_payment_terms.map(trainDataFrqMap)
trainData.head()
# Out:
#        USD  business_code  clear_date        doc_id  posting_date  \
# 16374    1          35430      737068  1.928539e+09        737058
# 34352    1          35430      737068  1.928534e+09        737058
# 26036    1          35430      737074  1.928542e+09        737058
# 14040    1          35430      737119  1.928517e+09        737058
# 14023    1          35430      737074  1.928539e+09        737058
#
#        document_create_date  due_in_date  total_open_amount  \
# 16374                737057       737073            4763.88
# 34352                737057       737073           15753.54
# 26036                737057       737073           12491.86
# 14040                737059       737058           17592.60
# 14023                737057       737073             116.38
#
#        baseline_create_date  cust_payment_terms    invoice_id  delay
# 16374                737058               10477  1.928539e+09     -5
# 34352                737058               10477  1.928534e+09     -5
# 26036                737058               10477  1.928542e+09      1
# 14040                737058                 565  1.928517e+09     61
# 14023                737058               15535  1.928539e+09      1

# %%
trainX = trainData['delay']
trainY = trainData['cust_payment_terms']
plt.scatter(trainX, trainY)
plt.xlabel("delay")
plt.ylabel("cust_payment_terms")
plt.title("delay vs cust_payment_terms")
# Out:
# Text(0.5, 1.0, 'delay vs cust_payment_terms')

# %%
import seaborn as sns
sns.relplot(x="business_code", y="delay", sort=False, kind="line", data=trainData)

# %%
trainX = trainData['delay']
trainY = trainData['posting_date']
plt.scatter(trainX, trainY)
plt.xlabel("delay")
plt.ylabel("posting_date")
plt.title("delay vs posting_date")
# Out:
# Text(0.5, 1.0, 'delay vs posting_date')

# %%
plt.figure(figsize=(6,6))
plt.figure(2)
sns.distplot(trainData['delay'], color='orange')
# Out:
# <AxesSubplot:xlabel='delay', ylabel='Density'>

# %%
plt.figure(figsize=(8,8))
plt.figure(1)
sns.distplot(trainData['total_open_amount'],color='red')
# Out:
# <AxesSubplot:xlabel='total_open_amount', ylabel='Density'>

# %%
testData.head()
# Out:
#    business_code cust_number        name_customer clear_date  buisness_year  \
# 0           U001  0200769623           WAL-MAR in        NaN         2020.0
# 2           U001      CCU013        KRAFT F trust        NaN         2020.0
# 10          U001  0200769623         WAL-MAR corp        NaN         2020.0
# 11          U001  0200769623  WAL-MAR corporation        NaN         2020.0
# 16          U001  0200769623         WAL-MAR corp        NaN         2020.0
#
#           doc_id posting_date  document_create_date  document_create_date.1  \
# 0   1.930815e+09   2020-04-28              20200422                20200428
# 2   1.930666e+09   2020-03-16              20200317                20200316
# 10  1.930711e+09   2020-03-28              20200327                20200328
# 11  1.930843e+09   2020-05-01              20200430                20200501
# 16  1.930838e+09   2020-04-29              20200429                20200429
#
#     due_in_date invoice_currency document type  posting_id  total_open_amount  \
# 0    20200513.0              USD            RV         1.0            6361.07
# 2    20200316.0              USD            RV         1.0            5095.68
# 10   20200412.0              USD            RV         1.0           31228.04
# 11   20200516.0              USD            RV         1.0           40491.29
# 16   20200514.0              USD            RV         1.0           18453.58
#
#     baseline_create_date cust_payment_terms    invoice_id  isOpen
# 0             20200428.0               NAH4  1.930815e+09       1
# 2             20200316.0               NAX2  1.930666e+09       1
# 10            20200328.0               NAH4  1.930711e+09       1
# 11            20200501.0               NAH4  1.930843e+09       1
# 16            20200429.0               NAH4  1.930838e+09       1

# %%
trainDataTemp = pd.get_dummies(testData['invoice_currency'],drop_first=True)
testData = pd.concat([trainDataTemp,testData],axis=1)
testData.drop('invoice_currency',axis=1,inplace=True)
testData.head()
# Out:
#     USD business_code cust_number        name_customer clear_date  \
# 0     1          U001  0200769623           WAL-MAR in        NaN
# 2     1          U001      CCU013        KRAFT F trust        NaN
# 10    1          U001  0200769623         WAL-MAR corp        NaN
# 11    1          U001  0200769623  WAL-MAR corporation        NaN
# 16    1          U001  0200769623         WAL-MAR corp        NaN
#
#     buisness_year        doc_id posting_date  document_create_date  \
# 0          2020.0  1.930815e+09   2020-04-28              20200422
# 2          2020.0  1.930666e+09   2020-03-16              20200317
# 10         2020.0  1.930711e+09   2020-03-28              20200327
# 11         2020.0  1.930843e+09   2020-05-01              20200430
# 16         2020.0  1.930838e+09   2020-04-29              20200429
#
#     document_create_date.1  due_in_date document type  posting_id  \
# 0                 20200428   20200513.0            RV         1.0
# 2                 20200316   20200316.0            RV         1.0
# 10                20200328   20200412.0            RV         1.0
# 11                20200501   20200516.0            RV         1.0
# 16                20200429   20200514.0            RV         1.0
#
#     total_open_amount  baseline_create_date cust_payment_terms    invoice_id  \
# 0             6361.07            20200428.0               NAH4  1.930815e+09
# 2             5095.68            20200316.0               NAX2  1.930666e+09
# 10           31228.04            20200328.0               NAH4  1.930711e+09
# 11           40491.29            20200501.0               NAH4  1.930843e+09
# 16           18453.58            20200429.0               NAH4  1.930838e+09
#
#     isOpen
# 0        1
# 2        1
# 10       1
# 11       1
# 16       1

# %%
trainDataFrqMap = testData.business_code.value_counts().to_dict()
testData.business_code = testData.business_code.map(trainDataFrqMap)
testData.head()
# Out:
#     USD  business_code cust_number        name_customer clear_date  \
# 0     1           9184  0200769623           WAL-MAR in        NaN
# 2     1           9184      CCU013        KRAFT F trust        NaN
# 10    1           9184  0200769623         WAL-MAR corp        NaN
# 11    1           9184  0200769623  WAL-MAR corporation        NaN
# 16    1           9184  0200769623         WAL-MAR corp        NaN
#
#     buisness_year        doc_id posting_date  document_create_date  \
# 0          2020.0  1.930815e+09   2020-04-28              20200422
# 2          2020.0  1.930666e+09   2020-03-16              20200317
# 10         2020.0  1.930711e+09   2020-03-28              20200327
# 11         2020.0  1.930843e+09   2020-05-01              20200430
# 16         2020.0  1.930838e+09   2020-04-29              20200429
#
#     document_create_date.1  due_in_date document type  posting_id  \
# 0                 20200428   20200513.0            RV         1.0
# 2                 20200316   20200316.0            RV         1.0
# 10                20200328   20200412.0            RV         1.0
# 11                20200501   20200516.0            RV         1.0
# 16                20200429   20200514.0            RV         1.0
#
#     total_open_amount  baseline_create_date cust_payment_terms    invoice_id  \
# 0             6361.07            20200428.0               NAH4  1.930815e+09
# 2             5095.68            20200316.0               NAX2  1.930666e+09
# 10           31228.04            20200328.0               NAH4  1.930711e+09
# 11           40491.29            20200501.0               NAH4  1.930843e+09
# 16           18453.58            20200429.0               NAH4  1.930838e+09
#
#     isOpen
# 0        1
# 2        1
# 10       1
# 11       1
# 16       1

# %%
trainData.head()
# Out:
#        USD  business_code  clear_date        doc_id  posting_date  \
# 16374    1          35430      737068  1.928539e+09        737058
# 34352    1          35430      737068  1.928534e+09        737058
# 26036    1          35430      737074  1.928542e+09        737058
# 14040    1          35430      737119  1.928517e+09        737058
# 14023    1          35430      737074  1.928539e+09        737058
#
#        document_create_date  due_in_date  total_open_amount  \
# 16374                737057       737073            4763.88
# 34352                737057       737073           15753.54
# 26036                737057       737073           12491.86
# 14040                737059       737058           17592.60
# 14023                737057       737073             116.38
#
#        baseline_create_date  cust_payment_terms    invoice_id  delay
# 16374                737058               10477  1.928539e+09     -5
# 34352                737058               10477  1.928534e+09     -5
# 26036                737058               10477  1.928542e+09      1
# 14040                737058                 565  1.928517e+09     61
# 14023                737058               15535  1.928539e+09      1

# %%
testData['clear_date'] = pd.to_datetime(testData.clear_date)
testData['posting_date'] = pd.to_datetime(testData.posting_date)
testData.head()

testData['document_create_date'] = pd.to_datetime(testData['document_create_date'], format='%Y%m%d')
testData['document_create_date.1'] = pd.to_datetime(testData['document_create_date.1'], format='%Y%m%d')

testData['due_in_date'] = testData['due_in_date'].astype(int)
testData['baseline_create_date'] = testData['baseline_create_date'].astype(int)

testData['due_in_date'] = pd.to_datetime(testData['due_in_date'], format='%Y%m%d')
testData['baseline_create_date'] = pd.to_datetime(testData['baseline_create_date'], format='%Y%m%d')
testData.head()
# Out:
#     USD  business_code cust_number        name_customer clear_date  \
# 0     1           9184  0200769623           WAL-MAR in        NaT
# 2     1           9184      CCU013        KRAFT F trust        NaT
# 10    1           9184  0200769623         WAL-MAR corp        NaT
# 11    1           9184  0200769623  WAL-MAR corporation        NaT
# 16    1           9184  0200769623         WAL-MAR corp        NaT
#
#     buisness_year        doc_id posting_date document_create_date  \
# 0          2020.0  1.930815e+09   2020-04-28           2020-04-22
# 2          2020.0  1.930666e+09   2020-03-16           2020-03-17
# 10         2020.0  1.930711e+09   2020-03-28           2020-03-27
# 11         2020.0  1.930843e+09   2020-05-01           2020-04-30
# 16         2020.0  1.930838e+09   2020-04-29           2020-04-29
#
#    document_create_date.1 due_in_date document type  posting_id  \
# 0              2020-04-28  2020-05-13            RV         1.0
# 2              2020-03-16  2020-03-16            RV         1.0
# 10             2020-03-28  2020-04-12            RV         1.0
# 11             2020-05-01  2020-05-16            RV         1.0
# 16             2020-04-29  2020-05-14            RV         1.0
#
#     total_open_amount baseline_create_date cust_payment_terms    invoice_id  \
# 0             6361.07           2020-04-28               NAH4  1.930815e+09
# 2             5095.68           2020-03-16               NAX2  1.930666e+09
# 10           31228.04           2020-03-28               NAH4  1.930711e+09
# 11           40491.29           2020-05-01               NAH4  1.930843e+09
# 16           18453.58           2020-04-29               NAH4  1.930838e+09
#
#     isOpen
# 0        1
# 2        1
# 10       1
# 11       1
# 16       1

# %%
testData['clear_date']=testData['clear_date'].map(dt.datetime.toordinal)
testData['posting_date']=testData['posting_date'].map(dt.datetime.toordinal)
testData['document_create_date']=testData['document_create_date'].map(dt.datetime.toordinal)
testData['document_create_date.1']=testData['document_create_date.1'].map(dt.datetime.toordinal)
testData['due_in_date']=testData['due_in_date'].map(dt.datetime.toordinal)
testData['baseline_create_date']=testData['baseline_create_date'].map(dt.datetime.toordinal)
testData.head()
# Out:
#     USD  business_code cust_number        name_customer  clear_date  \
# 0     1           9184  0200769623           WAL-MAR in           1
# 2     1           9184      CCU013        KRAFT F trust           1
# 10    1           9184  0200769623         WAL-MAR corp           1
# 11    1           9184  0200769623  WAL-MAR corporation           1
# 16    1           9184  0200769623         WAL-MAR corp           1
#
#     buisness_year        doc_id  posting_date  document_create_date  \
# 0          2020.0  1.930815e+09        737543                737537
# 2          2020.0  1.930666e+09        737500                737501
# 10         2020.0  1.930711e+09        737512                737511
# 11         2020.0  1.930843e+09        737546                737545
# 16         2020.0  1.930838e+09        737544                737544
#
#     document_create_date.1  due_in_date document type  posting_id  \
# 0                   737543       737558            RV         1.0
# 2                   737500       737500            RV         1.0
# 10                  737512       737527            RV         1.0
# 11                  737546       737561            RV         1.0
# 16                  737544       737559            RV         1.0
#
#     total_open_amount  baseline_create_date cust_payment_terms    invoice_id  \
# 0             6361.07                737543               NAH4  1.930815e+09
# 2             5095.68                737500               NAX2  1.930666e+09
# 10           31228.04                737512               NAH4  1.930711e+09
# 11           40491.29                737546               NAH4  1.930843e+09
# 16           18453.58                737544               NAH4  1.930838e+09
#
#     isOpen
# 0        1
# 2        1
# 10       1
# 11       1
# 16       1

# %%
testData.drop(columns=['cust_number','name_customer','buisness_year','document_create_date.1','document type','posting_id','isOpen'],inplace=True)
trainDataFrqMap = testData.cust_payment_terms.value_counts().to_dict()
testData.cust_payment_terms = testData.cust_payment_terms.map(trainDataFrqMap)
testData.head()
# Out:
#     USD  business_code  clear_date        doc_id  posting_date  \
# 0     1           9184           1  1.930815e+09        737543
# 2     1           9184           1  1.930666e+09        737500
# 10    1           9184           1  1.930711e+09        737512
# 11    1           9184           1  1.930843e+09        737546
# 16    1           9184           1  1.930838e+09        737544
#
#     document_create_date  due_in_date  total_open_amount  \
# 0                 737537       737558            6361.07
# 2                 737501       737500            5095.68
# 10                737511       737527           31228.04
# 11                737545       737561           40491.29
# 16                737544       737559           18453.58
#
#     baseline_create_date  cust_payment_terms    invoice_id
# 0                 737543                3011  1.930815e+09
# 2                 737500                  70  1.930666e+09
# 10                737512                3011  1.930711e+09
# 11                737546                3011  1.930843e+09
# 16                737544                3011  1.930838e+09

# %%
trainData.head()
# Out:
#        USD  business_code  clear_date        doc_id  posting_date  \
# 16374    1          35430      737068  1.928539e+09        737058
# 34352    1          35430      737068  1.928534e+09        737058
# 26036    1          35430      737074  1.928542e+09        737058
# 14040    1          35430      737119  1.928517e+09        737058
# 14023    1          35430      737074  1.928539e+09        737058
#
#        document_create_date  due_in_date  total_open_amount  \
# 16374                737057       737073            4763.88
# 34352                737057       737073           15753.54
# 26036                737057       737073           12491.86
# 14040                737059       737058           17592.60
# 14023                737057       737073             116.38
#
#        baseline_create_date  cust_payment_terms    invoice_id  delay
# 16374                737058               10477  1.928539e+09     -5
# 34352                737058               10477  1.928534e+09     -5
# 26036                737058               10477  1.928542e+09      1
# 14040                737058                 565  1.928517e+09     61
# 14023                737058               15535  1.928539e+09      1

# %%
testData.isnull().sum()
# Out:
# USD                     0
# business_code           0
# clear_date              0
# doc_id                  0
# posting_date            0
# document_create_date    0
# due_in_date             0
# total_open_amount       0
# baseline_create_date    0
# cust_payment_terms      0
# invoice_id              0
# dtype: int64

# %%
testData.duplicated().sum()
# Out:
# 278

# %%
testData.loc[testData.duplicated(),:]
# Out:
#        USD  business_code  clear_date        doc_id  posting_date  \
# 2292     1           9184           1  1.930775e+09        737526
# 2948     0            703           1  2.960626e+09        737520
# 3141     1           9184           1  1.930815e+09        737543
# 4962     1           9184           1  1.930654e+09        737502
# 5120     1           9184           1  1.930670e+09        737503
# ...    ...            ...         ...           ...           ...
# 49700    0            703           1  2.960633e+09        737549
# 49725    1           9184           1  1.930840e+09        737546
# 49732    1           9184           1  1.930582e+09        737483
# 49858    1           9184           1  1.930716e+09        737516
# 49860    1           9184           1  1.930779e+09        737532
#
#        document_create_date  due_in_date  total_open_amount  \
# 2292                 737526       737541           29819.97
# 2948                 737521       737538          150970.75
# 3141                 737537       737558            6361.07
# 4962                 737499       737517            3140.66
# 5120                 737502       737518           24521.34
# ...                     ...          ...                ...
# 49700                737549       737560            2248.45
# 49725                737545       737561           62242.42
# 49732                737483       737503            2226.63
# 49858                737512       737531              30.64
# 49860                737530       737547           61269.48
#
#        baseline_create_date  cust_payment_terms    invoice_id
# 2292                 737526                3011  1.930775e+09
# 2948                 737528                 696  2.960626e+09
# 3141                 737543                3011  1.930815e+09
# 4962                 737502                4096  1.930654e+09
# 5120                 737503                3011  1.930670e+09
# ...                     ...                 ...           ...
# 49700                737550                 696  2.960633e+09
# 49725                737546                4096  1.930840e+09
# 49732                737483                 103  1.930582e+09
# 49858                737516                3011  1.930716e+09
# 49860                737532                4096  1.930779e+09
#
# [278 rows x 11 columns]

# %%
testData.drop_duplicates(keep='first', inplace=True)
testData.shape
# Out:
# (9722, 11)

# %%
transposed = testData.T

# %%
transposed[transposed.duplicated(keep="first")]
# Out:
#                    0             2             10            11     \
# invoice_id  1.930815e+09  1.930666e+09  1.930711e+09  1.930843e+09
#
#                    16            21            25            28     \
# invoice_id  1.930838e+09  1.930653e+09  1.930830e+09  1.930624e+09
#
#                    29            30     ...         49957         49958  \
# invoice_id  1.930823e+09  1.930844e+09  ...  1.930848e+09  1.930813e+09
#
#                    49960         49965         49973         49980  \
# invoice_id  1.930704e+09  1.930577e+09  1.930854e+09  1.930862e+09
#
#                    49982         49983         49993         49997
# invoice_id  1.930826e+09  1.930760e+09  1.930660e+09  1.930838e+09
#
# [1 rows x 9722 columns]

# %%
testData = transposed.T.infer_objects()
testData.dtypes
# Out:
# USD                     float64
# business_code           float64
# clear_date              float64
# doc_id                  float64
# posting_date            float64
# document_create_date    float64
# due_in_date             float64
# total_open_amount       float64
# baseline_create_date    float64
# cust_payment_terms      float64
# invoice_id              float64
# dtype: object

# %%
testData.shape
# Out:
# (9722, 11)

# %%
trainData.dtypes
# Out:
# USD                       uint8
# business_code             int64
# clear_date                int64
# doc_id                  float64
# posting_date              int64
# document_create_date      int64
# due_in_date               int64
# total_open_amount       float64
# baseline_create_date      int64
# cust_payment_terms        int64
# invoice_id              float64
# delay                     int64
# dtype: object

# %%
from sklearn.ensemble import RandomForestClassifier
X = trainData[['business_code', 'posting_date', 'document_create_date',
       'due_in_date', 'USD', 'total_open_amount',
       'baseline_create_date', 'cust_payment_terms' ]]

Y = trainData['clear_date']

randomForestModel = RandomForestClassifier(n_estimators=20,random_state=11)

n_estimators = 25

random_state = 20

randomForestModel.fit(X, Y)
# Out:
# RandomForestClassifier(n_estimators=20, random_state=11)

# %%
featImpNum = randomForestModel.feature_importances_
featImpNum
# Out:
# array([0.00850241, 0.09632075, 0.15240377, 0.1199834 , 0.00450846,
#        0.38820617, 0.10557134, 0.1245037 ])

# %%
trainData.columns
# Out:
# Index(['USD', 'business_code', 'clear_date', 'doc_id', 'posting_date',
#        'document_create_date', 'due_in_date', 'total_open_amount',
#        'baseline_create_date', 'cust_payment_terms', 'invoice_id', 'delay'],
#       dtype='object')

# %%
trainData.corr()
# Out:
#                            USD  business_code  clear_date    doc_id  \
# USD                   1.000000       0.888140   -0.008121 -0.999605
# business_code         0.888140       1.000000   -0.012141 -0.900546
# clear_date           -0.008121      -0.012141    1.000000  0.010322
# doc_id               -0.999605      -0.900546    0.010322  1.000000
# posting_date         -0.005141       0.003463    0.993676  0.006569
# document_create_date -0.007353       0.002205    0.993497  0.008737
# due_in_date           0.004085       0.002103    0.995780 -0.002080
# total_open_amount    -0.192177      -0.158923    0.026949  0.191459
# baseline_create_date -0.012604      -0.003304    0.993631  0.014036
# cust_payment_terms    0.304997       0.363531   -0.023664 -0.310459
# invoice_id           -0.999605      -0.900546    0.010322  1.000000
# delay                -0.132834      -0.154984    0.036348  0.134942
#
#                       posting_date  document_create_date  due_in_date  \
# USD                      -0.005141             -0.007353     0.004085
# business_code             0.003463              0.002205     0.002103
# clear_date                0.993676              0.993497     0.995780
# doc_id                    0.006569              0.008737    -0.002080
# posting_date              1.000000              0.999917     0.995853
# document_create_date      0.999917              1.000000     0.995702
# due_in_date               0.995853              0.995702     1.000000
# total_open_amount         0.032165              0.033626     0.026064
# baseline_create_date      0.999630              0.999545     0.996083
# cust_payment_terms        0.009141              0.008807    -0.018670
# invoice_id                0.006569              0.008737    -0.002080
# delay                    -0.033241             -0.033562    -0.055519
#
#                       total_open_amount  baseline_create_date  \
# USD                           -0.192177             -0.012604
# business_code                 -0.158923             -0.003304
# clear_date                     0.026949              0.993631
# doc_id                         0.191459              0.014036
# posting_date                   0.032165              0.999630
# document_create_date           0.033626              0.999545
# due_in_date                    0.026064              0.996083
# total_open_amount              1.000000              0.034904
# baseline_create_date           0.034904              1.000000
# cust_payment_terms             0.039871              0.010141
# invoice_id                     0.191459              0.014036
# delay                          0.009376             -0.036249
#
#                       cust_payment_terms  invoice_id     delay
# USD                             0.304997   -0.999605 -0.132834
# business_code                   0.363531   -0.900546 -0.154984
# clear_date                     -0.023664    0.010322  0.036348
# doc_id                         -0.310459    1.000000  0.134942
# posting_date                    0.009141    0.006569 -0.033241
# document_create_date            0.008807    0.008737 -0.033562
# due_in_date                    -0.018670   -0.002080 -0.055519
# total_open_amount               0.039871    0.191459  0.009376
# baseline_create_date            0.010141    0.014036 -0.036249
# cust_payment_terms              1.000000   -0.310459 -0.054147
# invoice_id                     -0.310459    1.000000  0.134942
# delay                          -0.054147    0.134942  1.000000

# %%
X = trainData.drop(['clear_date', 'delay' ,'USD' , 'business_code', 'document_create_date'],axis = 1)
X.head()
# Out:
#              doc_id  posting_date  due_in_date  total_open_amount  \
# 16374  1.928539e+09        737058       737073            4763.88
# 34352  1.928534e+09        737058       737073           15753.54
# 26036  1.928542e+09        737058       737073           12491.86
# 14040  1.928517e+09        737058       737058           17592.60
# 14023  1.928539e+09        737058       737073             116.38
#
#        baseline_create_date  cust_payment_terms    invoice_id
# 16374                737058               10477  1.928539e+09
# 34352                737058               10477  1.928534e+09
# 26036                737058               10477  1.928542e+09
# 14040                737058                 565  1.928517e+09
# 14023                737058               15535  1.928539e+09

# %%
y = trainData['delay']
y.head()
# Out:
# 16374    -5
# 34352    -5
# 26036     1
# 14040    61
# 14023     1
# Name: delay, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(X_train,y_train)
lr_clf.score(X_test,y_test)
# Out:
# 0.0709481133863793

# %%
testData.head()
# Out:
#     USD  business_code  clear_date        doc_id  posting_date  \
# 0   1.0         9184.0         1.0  1.930815e+09      737543.0
# 2   1.0         9184.0         1.0  1.930666e+09      737500.0
# 10  1.0         9184.0         1.0  1.930711e+09      737512.0
# 11  1.0         9184.0         1.0  1.930843e+09      737546.0
# 16  1.0         9184.0         1.0  1.930838e+09      737544.0
#
#     document_create_date  due_in_date  total_open_amount  \
# 0               737537.0     737558.0            6361.07
# 2               737501.0     737500.0            5095.68
# 10              737511.0     737527.0           31228.04
# 11              737545.0     737561.0           40491.29
# 16              737544.0     737559.0           18453.58
#
#     baseline_create_date  cust_payment_terms    invoice_id
# 0               737543.0              3011.0  1.930815e+09
# 2               737500.0                70.0  1.930666e+09
# 10              737512.0              3011.0  1.930711e+09
# 11              737546.0              3011.0  1.930843e+09
# 16              737544.0              3011.0  1.930838e+09

# %%
X = trainData.drop(['delay','clear_date'],axis = 1)
X.head()
# Out:
#        USD  business_code        doc_id  posting_date  document_create_date  \
# 16374    1          35430  1.928539e+09        737058                737057
# 34352    1          35430  1.928534e+09        737058                737057
# 26036    1          35430  1.928542e+09        737058                737057
# 14040    1          35430  1.928517e+09        737058                737059
# 14023    1          35430  1.928539e+09        737058                737057
#
#        due_in_date  total_open_amount  baseline_create_date  \
# 16374       737073            4763.88                737058
# 34352       737073           15753.54                737058
# 26036       737073           12491.86                737058
# 14040       737058           17592.60                737058
# 14023       737073             116.38                737058
#
#        cust_payment_terms    invoice_id
# 16374               10477  1.928539e+09
# 34352               10477  1.928534e+09
# 26036               10477  1.928542e+09
# 14040                 565  1.928517e+09
# 14023               15535  1.928539e+09

# %%
y = trainData['delay']
y.head()
# Out:
# 16374    -5
# 34352    -5
# 26036     1
# 14040    61
# 14023     1
# Name: delay, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=10)

lr_clf = LinearRegression()
lr_clf.fit(X_train,y_train)
lr_clf.score(X_test,y_test)
# Out:
# 0.09075401288699092

# %%
from sklearn.ensemble import RandomForestRegressor
randomForestModel = RandomForestRegressor()
randomForestModel.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
randomForestModel.score(X_test, y_test)
# Out:
# 0.35495858685419013

# %%
testData.head()
# Out:
#     USD  business_code  clear_date        doc_id  posting_date  \
# 0   1.0         9184.0         1.0  1.930815e+09      737543.0
# 2   1.0         9184.0         1.0  1.930666e+09      737500.0
# 10  1.0         9184.0         1.0  1.930711e+09      737512.0
# 11  1.0         9184.0         1.0  1.930843e+09      737546.0
# 16  1.0         9184.0         1.0  1.930838e+09      737544.0
#
#     document_create_date  due_in_date  total_open_amount  \
# 0               737537.0     737558.0            6361.07
# 2               737501.0     737500.0            5095.68
# 10              737511.0     737527.0           31228.04
# 11              737545.0     737561.0           40491.29
# 16              737544.0     737559.0           18453.58
#
#     baseline_create_date  cust_payment_terms    invoice_id
# 0               737543.0              3011.0  1.930815e+09
# 2               737500.0                70.0  1.930666e+09
# 10              737512.0              3011.0  1.930711e+09
# 11              737546.0              3011.0  1.930843e+09
# 16              737544.0              3011.0  1.930838e+09

# %%
testData.drop(['clear_date'], axis=1, inplace=True)
testData['delay'] = randomForestModel.predict(testData)
testData.head()
# Out:
#     USD  business_code        doc_id  posting_date  document_create_date  \
# 0   1.0         9184.0  1.930815e+09      737543.0              737537.0
# 2   1.0         9184.0  1.930666e+09      737500.0              737501.0
# 10  1.0         9184.0  1.930711e+09      737512.0              737511.0
# 11  1.0         9184.0  1.930843e+09      737546.0              737545.0
# 16  1.0         9184.0  1.930838e+09      737544.0              737544.0
#
#     due_in_date  total_open_amount  baseline_create_date  cust_payment_terms  \
# 0      737558.0            6361.07              737543.0              3011.0
# 2      737500.0            5095.68              737500.0                70.0
# 10     737527.0           31228.04              737512.0              3011.0
# 11     737561.0           40491.29              737546.0              3011.0
# 16     737559.0           18453.58              737544.0              3011.0
#
#       invoice_id  delay
# 0   1.930815e+09   7.19
# 2   1.930666e+09 -11.49
# 10  1.930711e+09   6.81
# 11  1.930843e+09   6.16
# 16  1.930838e+09   8.67

# %%
testData['delay'] = testData.delay.astype(int)
testData.head()
# Out:
#     USD  business_code        doc_id  posting_date  document_create_date  \
# 0   1.0         9184.0  1.930815e+09      737543.0              737537.0
# 2   1.0         9184.0  1.930666e+09      737500.0              737501.0
# 10  1.0         9184.0  1.930711e+09      737512.0              737511.0
# 11  1.0         9184.0  1.930843e+09      737546.0              737545.0
# 16  1.0         9184.0  1.930838e+09      737544.0              737544.0
#
#     due_in_date  total_open_amount  baseline_create_date  cust_payment_terms  \
# 0      737558.0            6361.07              737543.0              3011.0
# 2      737500.0            5095.68              737500.0                70.0
# 10     737527.0           31228.04              737512.0              3011.0
# 11     737561.0           40491.29              737546.0              3011.0
# 16     737559.0           18453.58              737544.0              3011.0
#
#       invoice_id  delay
# 0   1.930815e+09      7
# 2   1.930666e+09    -11
# 10  1.930711e+09      6
# 11  1.930843e+09      6
# 16  1.930838e+09      8

# %%
testData['predicted_clear_date'] = testData['delay'] + testData['due_in_date']
testData.head()
# Out:
#     USD  business_code        doc_id  posting_date  document_create_date  \
# 0   1.0         9184.0  1.930815e+09      737543.0              737537.0
# 2   1.0         9184.0  1.930666e+09      737500.0              737501.0
# 10  1.0         9184.0  1.930711e+09      737512.0              737511.0
# 11  1.0         9184.0  1.930843e+09      737546.0              737545.0
# 16  1.0         9184.0  1.930838e+09      737544.0              737544.0
#
#     due_in_date  total_open_amount  baseline_create_date  cust_payment_terms  \
# 0      737558.0            6361.07              737543.0              3011.0
# 2      737500.0            5095.68              737500.0                70.0
# 10     737527.0           31228.04              737512.0              3011.0
# 11     737561.0           40491.29              737546.0              3011.0
# 16     737559.0           18453.58              737544.0              3011.0
#
#       invoice_id  delay  predicted_clear_date
# 0   1.930815e+09      7              737565.0
# 2   1.930666e+09    -11              737489.0
# 10  1.930711e+09      6              737533.0
# 11  1.930843e+09      6              737567.0
# 16  1.930838e+09      8              737567.0

# %%
def seg_val_bucket(x):
    t = []
    for i in list(x):
        if i<=0:
            t.append("(<=0) Days")
        elif (i> 0 and i<16):
            t.append("(0-15) Days")
        elif (i >= 16 and i<31): 
            t.append("(16-30) Days")
        elif (i >= 31 and i<46):
            t.append("(31-45) Days")
        elif (i >= 46 and i<61):
            t.append("(46-60) Days")
        else:
            t.append("(> 60) Days")
    return t

# %%
bucketVal = seg_val_bucket(testData['delay'])
testData['bucket_values'] = bucketVal
testData.head()
# Out:
#     USD  business_code        doc_id  posting_date  document_create_date  \
# 0   1.0         9184.0  1.930815e+09      737543.0              737537.0
# 2   1.0         9184.0  1.930666e+09      737500.0              737501.0
# 10  1.0         9184.0  1.930711e+09      737512.0              737511.0
# 11  1.0         9184.0  1.930843e+09      737546.0              737545.0
# 16  1.0         9184.0  1.930838e+09      737544.0              737544.0
#
#     due_in_date  total_open_amount  baseline_create_date  cust_payment_terms  \
# 0      737558.0            6361.07              737543.0              3011.0
# 2      737500.0            5095.68              737500.0                70.0
# 10     737527.0           31228.04              737512.0              3011.0
# 11     737561.0           40491.29              737546.0              3011.0
# 16     737559.0           18453.58              737544.0              3011.0
#
#       invoice_id  delay  predicted_clear_date bucket_values
# 0   1.930815e+09      7              737565.0   (0-15) Days
# 2   1.930666e+09    -11              737489.0    (<=0) Days
# 10  1.930711e+09      6              737533.0   (0-15) Days
# 11  1.930843e+09      6              737567.0   (0-15) Days
# 16  1.930838e+09      8              737567.0   (0-15) Days

# %%
sns.countplot(x = 'bucket_values', data = testData)
# Out:
# <AxesSubplot:xlabel='bucket_values', ylabel='count'>

# %%
testData['bucket_values'].value_counts()
# Out:
# (0-15) Days     7984
# (<=0) Days      1588
# (16-30) Days     146
# (31-45) Days       4
# Name: bucket_values, dtype: int64

# %%
y_predict = lr_clf.predict(X_test)

from sklearn import metrics
print('Mean Squared error : ',metrics.mean_squared_error(y_test, y_predict, squared=False))
print('Root Mean Squared error : ',np.sqrt(metrics.mean_squared_error(y_test, y_predict, squared=False)))
# Out:
# Mean Squared error :  10.127806411909404
# Root Mean Squared error :  3.1824214698731224

# %%
y_predict = randomForestModel.predict(X_test)

from sklearn import metrics
print('Mean Squared error : ',metrics.mean_squared_error(y_test, y_predict, squared=False))
print('Root Mean Squared error : ',np.sqrt(metrics.mean_squared_error(y_test, y_predict, squared=False)))
# Out:
# Mean Squared error :  8.530382279847975
# Root Mean Squared error :  2.9206818176323104

# %%
testData = testData.astype({'predicted_clear_date':'int32','posting_date':'int32','document_create_date':'int32','due_in_date':'int32','baseline_create_date':'int32'})

testData['predicted_clear_date']=testData['predicted_clear_date'].apply(dt.datetime.fromordinal)
testData['posting_date']=testData['posting_date'].apply(dt.datetime.fromordinal)
testData['document_create_date']=testData['document_create_date'].apply(dt.datetime.fromordinal)
testData['due_in_date']=testData['due_in_date'].apply(dt.datetime.fromordinal)
testData['baseline_create_date']=testData['baseline_create_date'].apply(dt.datetime.fromordinal)
testData.head()
# Out:
#     USD  business_code        doc_id posting_date document_create_date  \
# 0   1.0         9184.0  1.930815e+09   2020-04-28           2020-04-22
# 2   1.0         9184.0  1.930666e+09   2020-03-16           2020-03-17
# 10  1.0         9184.0  1.930711e+09   2020-03-28           2020-03-27
# 11  1.0         9184.0  1.930843e+09   2020-05-01           2020-04-30
# 16  1.0         9184.0  1.930838e+09   2020-04-29           2020-04-29
#
#    due_in_date  total_open_amount baseline_create_date  cust_payment_terms  \
# 0   2020-05-13            6361.07           2020-04-28              3011.0
# 2   2020-03-16            5095.68           2020-03-16                70.0
# 10  2020-04-12           31228.04           2020-03-28              3011.0
# 11  2020-05-16           40491.29           2020-05-01              3011.0
# 16  2020-05-14           18453.58           2020-04-29              3011.0
#
#       invoice_id  delay predicted_clear_date bucket_values
# 0   1.930815e+09      7           2020-05-20   (0-15) Days
# 2   1.930666e+09    -11           2020-03-05    (<=0) Days
# 10  1.930711e+09      6           2020-04-18   (0-15) Days
# 11  1.930843e+09      6           2020-05-22   (0-15) Days
# 16  1.930838e+09      8           2020-05-22   (0-15) Days

# %%
testData.dtypes
# Out:
# USD                            float64
# business_code                  float64
# doc_id                         float64
# posting_date            datetime64[ns]
# document_create_date    datetime64[ns]
# due_in_date             datetime64[ns]
# total_open_amount              float64
# baseline_create_date    datetime64[ns]
# cust_payment_terms             float64
# invoice_id                     float64
# delay                            int32
# predicted_clear_date    datetime64[ns]
# bucket_values                   object
# dtype: object

# %%
testData.reset_index(drop=True)
# Out:
#       USD  business_code        doc_id posting_date document_create_date  \
# 0     1.0         9184.0  1.930815e+09   2020-04-28           2020-04-22
# 1     1.0         9184.0  1.930666e+09   2020-03-16           2020-03-17
# 2     1.0         9184.0  1.930711e+09   2020-03-28           2020-03-27
# 3     1.0         9184.0  1.930843e+09   2020-05-01           2020-04-30
# 4     1.0         9184.0  1.930838e+09   2020-04-29           2020-04-29
# ...   ...            ...           ...          ...                  ...
# 9717  1.0         9184.0  1.930862e+09   2020-05-06           2020-05-06
# 9718  1.0         9184.0  1.930826e+09   2020-04-25           2020-04-25
# 9719  1.0         9184.0  1.930760e+09   2020-04-09           2020-04-07
# 9720  1.0         9184.0  1.930660e+09   2020-03-17           2020-03-16
# 9721  1.0         9184.0  1.930838e+09   2020-05-02           2020-04-29
#
#      due_in_date  total_open_amount baseline_create_date  cust_payment_terms  \
# 0     2020-05-13            6361.07           2020-04-28              3011.0
# 1     2020-03-16            5095.68           2020-03-16                70.0
# 2     2020-04-12           31228.04           2020-03-28              3011.0
# 3     2020-05-16           40491.29           2020-05-01              3011.0
# 4     2020-05-14           18453.58           2020-04-29              3011.0
# ...          ...                ...                  ...                 ...
# 9717  2020-05-21          171301.72           2020-05-06              4096.0
# 9718  2020-05-09            2241.22           2020-04-16               260.0
# 9719  2020-04-24            6540.07           2020-04-09              3011.0
# 9720  2020-05-21            6276.46           2020-03-17               307.0
# 9721  2020-05-17            7595.36           2020-05-02              3011.0
#
#         invoice_id  delay predicted_clear_date bucket_values
# 0     1.930815e+09      7           2020-05-20   (0-15) Days
# 1     1.930666e+09    -11           2020-03-05    (<=0) Days
# 2     1.930711e+09      6           2020-04-18   (0-15) Days
# 3     1.930843e+09      6           2020-05-22   (0-15) Days
# 4     1.930838e+09      8           2020-05-22   (0-15) Days
# ...            ...    ...                  ...           ...
# 9717  1.930862e+09      2           2020-05-23   (0-15) Days
# 9718  1.930826e+09     -1           2020-05-08    (<=0) Days
# 9719  1.930760e+09      7           2020-05-01   (0-15) Days
# 9720  1.930660e+09      0           2020-05-21    (<=0) Days
# 9721  1.930838e+09      7           2020-05-24   (0-15) Days
#
# [9722 rows x 13 columns]
